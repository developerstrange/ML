# %%
'''
Machine Learning:
  Machine Learning is a field of computer science that uses statistical techinques to give computer systems the ability to learn with data without being explicitly programmed.

Data Mining:
  Data mining is the process of analyzing massive datasets using statistical, machine learning, and computational techniques.
  It uncovers hidden patterns, anomalies, and correlations to transform raw data into actionable insights for predicting future trends and driving informed decision-making.
  Data mining bridges the gap between applied statistics, artificial intelligence, and database management.

  How it works:
  1. Data Gathering & Warehousing: Consolidating data from various sources into a central location.
  2. Data Cleansing & Preprocessing: Removing errors, filling missing values, and organizing the data.
  3. Pattern Mining: Using algorithms to identify trends, associations, or anomalies.

Artificial Intelligence:
  Artificial intelligence is the field of computer science focused on creating systems that can perform tasks requiring human-like intelligence such as reasoning, problem-solving, planning and understanding natural language. (https://www.geeksforgeeks.org/artificial-intelligence/artificial-intelligence-vs-machine-learning-vs-deep-learning/)
  It includes rule-based systems as well as data-driven approaches like ML and DL.

Machine Learning:
  Machine Learning is a branch of AI that enables systems to learn from data and improve their performance without being explicitly programmed. Instead of following fixed rules, ML algorithms analyze past data, detect patterns and use them to make predictions or decisions in new situations. (https://www.geeksforgeeks.org/artificial-intelligence/artificial-intelligence-vs-machine-learning-vs-deep-learning/)
  Learns from structured and labeled datasets.

Deep Learning:
  Deep Learning is a subset of machine learning that uses artificial neural networks with many layers to automatically learn complex patterns from large datasets. Unlike traditional ML, it can extract features on its own making it useful for handling unstructured data such as images, speech and text. (https://www.geeksforgeeks.org/artificial-intelligence/artificial-intelligence-vs-machine-learning-vs-deep-learning/)
  Learns from unstructured data.
  DL is made of many layers where every layers uncovers more hidden patterns and give us more accurate results where ML is not made of many layers.
  So it's difficult for ML to uncovers most hidded patterns in unstructured data. ML can perform well in small dataset where DL can perform well in many and broad dataset including unstructured data.
  As many layers data cross, the more critical patterns uncovers and every layer is connected in DL where one layer can use the previous layer results.
'''
